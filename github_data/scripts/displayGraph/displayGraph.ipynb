# %%
import sys
sys.path.insert(0,"../../")
import networkx as nx
from itertools import combinations
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import scripts.utils.helper_methods as helper_methods
from networkx.algorithms import bipartite
import time
import matplotlib.pyplot as plt


graphFile = "../../graphs/final/finalConnectedGraph.gexf"

# %%
try:
    gph = nx.read_gexf(graphFile)
    helper_methods.logData("graph file found at " + str())
except Exception as e:
    helper_methods.logData(e)
    gph = nx.Graph()
    helper_methods.logData("new graph file generated")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       2     gph = nx.read_gexf(graphFile)
# ----> 3     helper_methods.logData("graph file found at " + str())
#       4 except Exception as e:
#
# File /media/theparadoxica/New Volume/Documents/College/Sem 6/Social_Network_Analysis/issue-recommendation/github_data/scripts/displayGraph/../../scripts/utils/helper_methods.py:106, in logData(logVal)
#     105 def logData(logVal):
# --> 106     with open("../data/logs/logs.json", "a") as outfile:
#     107         outfile.write(str(logVal))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/logs/logs.json'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 5
#       3     helper_methods.logData("graph file found at " + str())
#       4 except Exception as e:
# ----> 5     helper_methods.logData(e)
#       6     gph = nx.Graph()
#       7     helper_methods.logData("new graph file generated")
#
# File /media/theparadoxica/New Volume/Documents/College/Sem 6/Social_Network_Analysis/issue-recommendation/github_data/scripts/displayGraph/../../scripts/utils/helper_methods.py:106, in logData(logVal)
#     105 def logData(logVal):
# --> 106     with open("../data/logs/logs.json", "a") as outfile:
#     107         outfile.write(str(logVal))
#     108         outfile.write("\n")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/logs/logs.json'

# %%
count = 40
sampleNodeList = []
sampleEdgeList = []

userList = []
for n in gph.nodes(data = True):
    sampleNodeList.append(str(n[0]))
    
    if(n[1]['bipartite'] == 0):
        userList.append(str(n[0]))
    
    count -= 1
    if(count == 0):
        break
    
print(userList)
# Out:
# ['lapce', 'lucalewin', 'SirNiklax', 'DJMcNab', 'hbina', 'rezaxdi', 'tk103331', 'ChristianKleineidam', 'dart-lang', 'stuartmorgan', 'ntkme', 'bytes7bytes7']

# %%
# subgraph_nodes = [1, 2, 'a', 'b', 'c', 'd', 'e', 'f']
subgraph = gph.subgraph(sampleNodeList)


        
pos = nx.bipartite_layout(subgraph, userList)
nx.draw(subgraph, pos, with_labels=True)
plt.show()

# %%
nx.draw_networkx(gph, with_labels=True,nodelist=sampleNodeList, node_size=20,width=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 nx.draw_networkx(gph, with_labels=True,nodelist=sampleNodeList, node_size=20,width=0.2)
#       2 plt.show()
#
# File ~/.local/lib/python3.10/site-packages/networkx/drawing/nx_pylab.py:301, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     298 label_kwds = {k: v for k, v in kwds.items() if k in valid_label_kwds}
#     300 if pos is None:
# --> 301     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     303 draw_networkx_nodes(G, pos, **node_kwds)
#     304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#
# File ~/.local/lib/python3.10/site-packages/networkx/utils/decorators.py:766, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     765 def func(*args, __wrapper=None, **kwargs):
# --> 766     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 13:4, in argmap_spring_layout_10(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File ~/.local/lib/python3.10/site-packages/networkx/drawing/layout.py:482, in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     480         nnodes, _ = A.shape
#     481         k = dom_size / np.sqrt(nnodes)
# --> 482     pos = _sparse_fruchterman_reingold(
#     483         A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     484     )
#     485 except ValueError:
#     486     A = nx.to_numpy_array(G, weight=weight)
#
# File ~/.local/lib/python3.10/site-packages/networkx/utils/decorators.py:766, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     765 def func(*args, __wrapper=None, **kwargs):
# --> 766     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 17:4, in argmap__sparse_fruchterman_reingold_14(A, k, pos, fixed, iterations, threshold, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File ~/.local/lib/python3.10/site-packages/networkx/drawing/layout.py:624, in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     622     Ai = A.getrowview(i).toarray()  # TODO: revisit w/ sparse 1D container
#     623     # displacement "force"
# --> 624     displacement[:, i] += (
#     625         delta * (k * k / distance**2 - Ai * distance / k)
#     626     ).sum(axis=1)
#     627 # update positions
#     628 length = np.sqrt((displacement**2).sum(axis=0))
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py:46, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
#      44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
# ---> 46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
#      48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      51           initial=_NoValue, where=True):
#
# KeyboardInterrupt:
