# %%
import networkx as nx
import random
import time
import sys
sys.path.insert(0,"../../")
import scripts.utils.helper_methods as helper_methods

# %%
gph = nx.read_gexf("../../graphs/v3/contribConnected.gexf")

# %%
B = gph

users = [n for n, d in B.nodes(data=True) if d["bipartite"] == 0]
issues = [n for n, d in B.nodes(data=True) if d["bipartite"] == 1]

# %%
def jaccard_coefficient(graph, node1, node2):
    helper_methods.logData("Node 1 ------" + str(node1))
    helper_methods.logData("Node 2 ------" + str(node2))
     
    neighbors1 = set(graph.neighbors(node1))
    
    helper_methods.logData("---------Set of Neighbours of Node 1 ---------")
    helper_methods.logData(neighbors1)
    neighbors2 = set(graph.neighbors(node2))
    
    helper_methods.logData("---------Set of Neighbours of Node 2 ---------")
    helper_methods.logData(neighbors2)
    
    helper_methods.logData("------ Intersection ------")
    intersection = neighbors1.intersection(neighbors2)
    helper_methods.logData(intersection)
    
    helper_methods.logData("----------Union------------")
    union = neighbors1.union(neighbors2)
    helper_methods.logData(union)
    # time.sleep(10)
    
    
    if len(union) == 0:
        return 0
    return len(intersection) / len(union)

# %%
def jaccard_link_prediction(graph, threshold):
    predicted_edges = []
    
    userCount = 0
    for node1 in users:
        userCount += 1
        for node2 in issues:
            if node1 == node2 or graph.has_edge(node1, node2):
                continue
            jaccard = jaccard_coefficient(graph, node1, node2)
            if(jaccard >= threshold):
                predicted_edges.append((node1, node2, jaccard))
                    
    return sorted(predicted_edges, key=lambda x: x[2], reverse=True)

# %%
def removeEdges(graph):
    g = nx.Graph()
    initial = graph.number_of_edges()
    # issuesList = random.sample(issues, 2000)
    icount = 0
    for i in issues:
        icount += 1
        if(icount %5) == 0:
            issuesList.append(i)
        
    for i in issuesList:
        for j in list(graph.neighbors(i)):
            if graph.nodes[j]["bipartite"] == 0:
                g.add_node(i, bipartite=1)
                g.add_node(j, bipartite=0)
                g.add_edge(i,j)
                graph.remove_edge(i,j)
    final = graph.number_of_edges()
    print(initial - final)
    return g,graph

# %%
G = B
og, test = removeEdges(G)
# Out:
# 2000

# %%
pred_list = jaccard_link_prediction(test, 0.05)
# Out:
# Node 1 ------lapce
# Node 2 ------PR_kwDOBy2NM85K9kR7
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85JlbVF', 'lucalewin', 'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85I_fpj', 'PR_kwDOBy2NM85I9VzR', 'PR_kwDOBy2NM85Jg1hg', 'PR_kwDOBy2NM85IwBBx', 'PR_kwDOBy2NM85JIddY', 'PR_kwDOBy2NM85I5ljj', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85K9bUt', 'PR_kwDOBy2NM85JKB2s', 'PR_kwDOBy2NM85JSYCA'}
# ------ Intersection ------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# ----------Union------------
# {'PR_kwDOBy2NM85JlbVF', 'PR_kwDOBy2NM85I9VzR', 'PR_kwDOBy2NM85Jg1hg', 'PR_kwDOBy2NM85IwBBx', 'PR_kwDOBy2NM85JIddY', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85K9bUt', 'PR_kwDOBy2NM85JSYCA', 'lucalewin', 'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85I_fpj', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85I5ljj', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85JKB2s'}
# Node 1 ------lapce
# Node 2 ------PR_kwDOBy2NM85K9bUt
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ', 'SirNiklax', 'PR_kwDOBy2NM85K9kR7'}
# ------ Intersection ------
# {'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ'}
# ----------Union------------
# {'PR_kwDOBy2NM85Jeo7e', 'SirNiklax', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85K9kR7', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# Node 1 ------lapce
# Node 2 ------PR_kwDOBy2NM85KdiNI
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# ---------Set of Neighbours of Node 1 ---------
# {'DJMcNab'}
# ------ Intersection ------
# set()
# ----------Union------------
# {'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85Jeo7e', 'DJMcNab', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s', 'PR_kwDOBy2NM85JIfZE'}
# Node 1 ------lapce
# Node 2 ------PR_kwDOBy2NM85JlbVF
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# ---------Set of Neighbours of Node 1 ---------
# {'hbina', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85K9kR7'}
# ------ Intersection ------
# {'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ'}
# ----------Union------------
# {'PR_kwDOBy2NM85Jeo7e', 'hbina', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85K9kR7', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# Node 1 ------lapce
# Node 2 ------PR_kwDOBy2NM85Jg1hg
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85K9kR7'}
# ------ Intersection ------
# {'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ'}
# ----------Union------------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85K9kR7', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# Node 1 ------lapce
# Node 2 ------PR_kwDOBy2NM85JSYCA
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85K9kR7'}
# ------ Intersection ------
# {'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ'}
# ----------Union------------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85K9kR7', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# Node 1 ------lapce
# Node 2 ------PR_kwDOBy2NM85JIddY
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# ---------Set of Neighbours of Node 1 ---------
# {'hbina', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85K9kR7'}
# ------ Intersection ------
# {'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85LAawJ'}
# ----------Union------------
# {'PR_kwDOBy2NM85Jeo7e', 'hbina', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85K9kR7', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# Node 1 ------lapce
# Node 2 ------PR_kwDOBy2NM85I_fpj
# ---------Set of Neighbours of Node 1 ---------
# {'PR_kwDOBy2NM85Jeo7e', 'PR_kwDOBy2NM85JIfZE', 'PR_kwDOBy2NM85LQJYb', 'PR_kwDOBy2NM85JX6tb', 'PR_kwDOBy2NM85LAawJ', 'PR_kwDOBy2NM85JKB2s'}
# ---------Set of Neighbours of Node 1 ---------
# {
}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pred_list = jaccard_link_prediction(test, 0.05)
#
# Cell In[7], line 10, in jaccard_link_prediction(graph, threshold)
#       8 if node1 == node2 or graph.has_edge(node1, node2):
#       9     continue
# ---> 10 jaccard = jaccard_coefficient(graph, node1, node2)
#      11 if(jaccard >= threshold):
#      12     predicted_edges.append((node1, node2, jaccard))
#
# Cell In[6], line 21, in jaccard_coefficient(graph, node1, node2)
#      19 union = neighbors1.union(neighbors2)
#      20 print(union)
# ---> 21 time.sleep(10)
#      24 if len(union) == 0:
#      25     return 0
#
# KeyboardInterrupt:

# %%
og_list = og.edges()
og_list = list(og_list)

# %%
for i in range(len(pred_list)):
    pred_list[i] = pred_list[i][:2]
# print(pred_list)

# %%
common_edges = []

for edge1 in pred_list:
    for edge2 in og_list:
        sorted_edge1 = tuple(sorted(edge1))
        sorted_edge2 = tuple(sorted(edge2))
        if sorted_edge1 == sorted_edge2:
            common_edges.append(edge1)
            break

# %%
print(len(common_edges))
for i in common_edges:
    print(i)
# Out:
# 7
# ('lapce', 'PR_kwDOBy2NM85JX6tb')
# ('lapce', 'PR_kwDOBy2NM85JKB2s')
# ('ntkme', 'PR_kwDOBFHeo85FsQoC')
# ('ntkme', 'PR_kwDOAiEj5s5HPd6W')
# ('login', 'MDExOlB1bGxSZXF1ZXN0OTk4MjkwMTA=')
# ('login', 'MDExOlB1bGxSZXF1ZXN0MTI3MDE3ODAw')
# ('login', 'MDExOlB1bGxSZXF1ZXN0MTIxMjM3Njc0')

# %%
# Changing Threshold to 0.1

test1 = jaccard_link_prediction(test, 0.1)

for i in range(len(test1)):
    test1[i] = test1[i][:2]

commonTest1 = []

for edge1 in test1:
    for edge2 in og_list:
        sorted_edge1 = tuple(sorted(edge1))
        sorted_edge2 = tuple(sorted(edge2))
        if sorted_edge1 == sorted_edge2:
            commonTest1.append(edge1)
            break

print(len(commonTest1))
for i in commonTest1:
    print(i)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 2
# ('lapce', 'PR_kwDOBy2NM85JX6tb')
# ('lapce', 'PR_kwDOBy2NM85JKB2s')

# %%
# Changing Threshold to 0.2

test2 = jaccard_link_prediction(test, 0.2)

for i in range(len(test2)):
    test2[i] = test2[i][:2]

commonTest2 = []

for edge1 in test2:
    for edge2 in og_list:
        sorted_edge1 = tuple(sorted(edge1))
        sorted_edge2 = tuple(sorted(edge2))
        if sorted_edge1 == sorted_edge2:
            commonTest2.append(edge1)
            break

print(len(commonTest2))
for i in commonTest2:
    print(i)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 2
# ('lapce', 'PR_kwDOBy2NM85JX6tb')
# ('lapce', 'PR_kwDOBy2NM85JKB2s')

# %%
# Changing Threshold to 0.01

test3 = jaccard_link_prediction(test, 0.01)

for i in range(len(test3)):
    test3[i] = test3[i][:2]

commonTest3 = []

for edge1 in test3:
    for edge2 in og_list:
        sorted_edge1 = tuple(sorted(edge1))
        sorted_edge2 = tuple(sorted(edge2))
        if sorted_edge1 == sorted_edge2:
            commonTest3.append(edge1)
            break

print(len(commonTest3))
for i in commonTest3:
    print(i)
# Out:
# 100
# CNjacob-------PR_kwDOAKJ_Hs5Jv_h_-------0.022727272727272728
# 200
# 300
# 400
# ryojiro-------PR_kwDOC60iJ85KdgRL-------0.01694915254237288
# 500
# 600
# vursin-------PR_kwDOFCXpoc46Irxg-------0.013513513513513514
# 700
# 800
# 900
# S34NW-------MDExOlB1bGxSZXF1ZXN0MTU2ODcxOTUy-------0.010638297872340425
# 1000
# KillianKirilenko-------PR_kwDOA3k59s5KwvTs-------0.012658227848101266
# 1100
# 1200
# Superspheres-------MDExOlB1bGxSZXF1ZXN0NTQ1MDc3NjIw-------0.011363636363636364
# 1300
# EdwardNashton-------MDExOlB1bGxSZXF1ZXN0Njc1Njk0NDk3-------0.027777777777777776
# 1400
# 1500
# CoZarctan-------MDExOlB1bGxSZXF1ZXN0NjkyNDQzMTM5-------0.01694915254237288
# 1600
# 1700
# 1800
# 1900
# 2000
# gosimitz-------MDExOlB1bGxSZXF1ZXN0MTkyMzY0NDky-------0.015625
# 2100
# 2200
# 2300
# 2400
# 2500
# BeatConnect-------PR_kwDOAMKNF85KH7iz-------0.02857142857142857
# 2600
# 2700
# 2800
# 2900
# josedelinux-------MDExOlB1bGxSZXF1ZXN0MTUzNDI5Mzg1-------0.012658227848101266
# 3000
# 3100
# 19
# ('lapce', 'PR_kwDOBy2NM85JX6tb')
# ('lapce', 'PR_kwDOBy2NM85JKB2s')
# ('ntkme', 'PR_kwDOBFHeo85FsQoC')
# ('ntkme', 'PR_kwDOAiEj5s5HPd6W')
# ('login', 'MDExOlB1bGxSZXF1ZXN0OTk4MjkwMTA=')
# ('login', 'MDExOlB1bGxSZXF1ZXN0MTI3MDE3ODAw')
# ('login', 'MDExOlB1bGxSZXF1ZXN0MTIxMjM3Njc0')
# ('FarmBot', 'PR_kwDOAPHTvM453e0k')
# ('FarmBot', 'PR_kwDOAPHTvM42MO82')
# ('FarmBot', 'PR_kwDOAPHTvM4x3zO_')
# ('FarmBot', 'PR_kwDOAPHTvM4xssyI')
# ('FarmBot', 'PR_kwDOAPHTvM4xn40Q')
# ('SS13-SCP13', 'MDExOlB1bGxSZXF1ZXN0MjM4OTgzNTM5')
# ('kaina404', 'MDExOlB1bGxSZXF1ZXN0MjYzMTA4MTQ0')
# ('KanohaShinobi', 'MDExOlB1bGxSZXF1ZXN0MzE4NTgzMzcx')
# ('KanohaShinobi', 'MDExOlB1bGxSZXF1ZXN0MzE1Nzc0OTg2')
# ('KanohaShinobi', 'MDExOlB1bGxSZXF1ZXN0Mjc3MjMwNjg2')
# ('Tarmunora', 'MDExOlB1bGxSZXF1ZXN0Mzk0NTU3MjA2')
# ('Tarmunora', 'MDExOlB1bGxSZXF1ZXN0MzgyMDk1NTQ3')
