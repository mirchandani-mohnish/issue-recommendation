# %%
import networkx as nx
from itertools import combinations
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import fileDefinitions as fd
import utils.helper_methods as helper_methods
from networkx.algorithms import bipartite
import time

# %%
try:
    # gph = nx.read_gexf(fd.fullyConnGraphFile)
    # helper_methods.logData("graph file found at " + str())
    gph = nx.read_gexf("./fullyConnGraph.gexf")
except Exception as e:
    helper_methods.logData(e)
    gph = nx.Graph()
    helper_methods.logData("new graph file generated")

# %%
B = gph
# users = []
# issues = []
# for n in B:
#     if(n == 0):
#         users.append(n)
#     else:
#         issues.append(n)
users = [n for n, d in B.nodes(data=True) if d["bipartite"] == 0]
issues = [n for n, d in B.nodes(data=True) if d["bipartite"] == 1]

# %%
# create adjacency matrices for the users and issues
users_matrix = nx.bipartite.biadjacency_matrix(B, row_order=users)
issues_matrix = nx.bipartite.biadjacency_matrix(B, row_order=issues)

# %%
print(issues_matrix[:,[1]])
# Out:
#   (2969, 0)	1
#   (2970, 0)	1
#   (2971, 0)	1
#   (2972, 0)	1
#   (2977, 0)	1
#   (2984, 0)	1
#   (2990, 0)	1
#   (2994, 0)	1

# %%
def jaccard_coefficient(graph, node1, node2):
    neighbors1 = set(graph.neighbors(node1))
    neighbors2 = set(graph.neighbors(node2))
    intersection = neighbors1.intersection(neighbors2)
    union = neighbors1.union(neighbors2)
    if len(union) == 0:
        return 0
    return len(intersection) / len(union)

# %%
def jaccard_link_prediction(graph):
    predicted_edges = []
    count = 10000
    userCount = 0
    for node1 in users:
        
        userCount += 1
        if(userCount%100 == 0):
            print(userCount)
        for node2 in issues:
            
            if node1 == node2 or graph.has_edge(node1, node2):
                continue
            
            jaccard = jaccard_coefficient(graph, node1, node2)
            if(jaccard != 0):
                predicted_edges.append((node1, node2, jaccard))
                count -= 1
                if(count == 0):
                    print(node1,end="-------")
                    print(node2, end="-------")
                    print(jaccard)
                    count = 10000
                    
    return sorted(predicted_edges, key=lambda x: x[2], reverse=True)

# %%
print(B)
print(len(users))
print(len(issues))
# Out:
# Graph with 11406 nodes and 1391375 edges
# 3126
# 8280

# %%
print("Node1 ------ Node2 ------ Jacord Coeff")
print(jaccard_link_prediction(B))
# Out:
# Node1 ------ Node2 ------ Jacord Coeff
# stuartmorgan-------PR_kwDOCGzUbs5JeGV7-------0.0007012622720897616
# cpswan-------MDExOlB1bGxSZXF1ZXN0Mzk3MTI4NTE5-------0.0006711409395973154
# GIfatahTH-------MDExOlB1bGxSZXF1ZXN0Mzg1NDQwMTcw-------0.0006557377049180328
# aouahib-------PR_kwDOCGzUbs5KXmy--------0.0006514657980456026
# mazihao66-------MDExOlB1bGxSZXF1ZXN0NDk1OTU2MTI1-------0.000700770847932726
# Wanchen7-------MDExOlB1bGxSZXF1ZXN0MzQzODYzMjY5-------0.002036659877800407
# EightMinuteYouth-------PR_kwDOB40ng85I_BMH-------0.0013477088948787063
# gendseo-------PR_kwDOD0USHc5LIk5j-------0.0006765899864682003
# mishrabhilash-------PR_kwDOD0USHc5KP8qy-------0.0006993006993006993
# socialmad-------MDExOlB1bGxSZXF1ZXN0NTcwMTYzODEw-------0.0006978367062107466
# SakurasDuck-------PR_kwDOEG4Joc49HsRQ-------0.000657030223390276
# chejdj-------MDExOlB1bGxSZXF1ZXN0NDk3Mjg4NjE5-------0.0006724949562878278
# mridul-dhiman-------MDExOlB1bGxSZXF1ZXN0Mjc4MDI3MTc5-------0.0006540222367560497
# 100
# Mohit-Joshi-dev-------PR_kwDOCkCuKM44ISvP-------0.000700770847932726
# RohanSengupta326-------MDExOlB1bGxSZXF1ZXN0NDY5NjcwODEw-------0.0006997900629811056
# mohammadrezayousefpour-------MDExOlB1bGxSZXF1ZXN0Mjc0OTQ1MzA5-------0.0007017543859649122
# flame-engine-------MDExOlB1bGxSZXF1ZXN0Mzk5NzU5MTU3-------0.01951219512195122
# Gustl22-------MDExOlB1bGxSZXF1ZXN0NTMyMjk5MDg5-------0.0010964912280701754
# Icosa2050-------PR_kwDODYvhJM41ZWRR-------0.0006734006734006734
# metinn-------MDExOlB1bGxSZXF1ZXN0NjEzOTAyMDM=-------0.007407407407407408
# alonelucky-------PR_kwDOBhDmg849A0tq-------0.0006854009595613434
# vicxia-------MDExOlB1bGxSZXF1ZXN0NTM3MTc1MjU5-------0.0006949270326615705
# RivaanRanawat-------PR_kwDOCmABf85CMYQP-------0.001326259946949602
# priteshkeleven-------MDExOlB1bGxSZXF1ZXN0MjQ5OTEyMjIw-------0.0006775067750677507
# alaazamelDev-------PR_kwDOBQvi-84sNSRW-------0.0006489292667099286
# ajumalp-------PR_kwDOBfYDC84so5Jt-------0.0006949270326615705
# isaacadariku-------MDExOlB1bGxSZXF1ZXN0MjM4ODk4NTQ2-------0.0006402048655569782
# 200
# Wizzel1-------PR_kwDOBhDmg848mfjs-------0.0007017543859649122
# Ayad-Ben-Saliem-------MDExOlB1bGxSZXF1ZXN0Mzc4NTk4OTM4-------0.001221001221001221
# XuYanci-------MDExOlB1bGxSZXF1ZXN0NTkwMDM1NDk2-------0.0011655011655011655
# tomi-msft-------MDExOlB1bGxSZXF1ZXN0MTAxMDE3Njc5-------0.002807017543859649
# Ambikadulal-------MDExOlB1bGxSZXF1ZXN0NjU0MjExMzEy-------0.01590594744121715
# oscarrock-------MDExOlB1bGxSZXF1ZXN0MTExNjUyODM4-------0.0011876484560570072
# mj-hd-------PR_kwDOCSpvU84w6Zh8-------0.0011806375442739079
# andrewkolos-------PR_kwDOBfYDC85A36G0-------0.0007017543859649122
# jonahwilliams-------MDExOlB1bGxSZXF1ZXN0MjE0MDg0Nzkx-------0.001199040767386091
# Nikit-370-------PR_kwDOAJ9R5M5JPkGm-------0.0006868131868131869
# edTheGuy00-------MDExOlB1bGxSZXF1ZXN0Njg2MTc3NjQy-------0.001098901098901099
# 300
# Stitch-Taotao-------PR_kwDODYvhJM44qN-D-------0.0006798096532970768
# Pwuts-------PR_kwDODTUYG85DsMdT-------0.0006830601092896175
# hkloudou-------MDExOlB1bGxSZXF1ZXN0MTk4Nzg0MzY=-------0.00066711140760507
# galaxybruce-------MDExOlB1bGxSZXF1ZXN0NDgwNTYzNzA0-------0.0006901311249137336
# caihua-------PR_kwDOB2vfUM4xkZTS-------0.0007017543859649122
# frg2089-------MDExOlB1bGxSZXF1ZXN0Njg2MTc3NjQy-------0.002369668246445498
# m4b-------PR_kwDOCF04Ls4wCdIt-------0.001215066828675577
# setcy-------PR_kwDOAClxHc5K3UW3-------0.0006901311249137336
# LeoAndo-------MDExOlB1bGxSZXF1ZXN0NTQyMzg2ODE0-------0.0006743088334457181
# j-j-gajjar-------PR_kwDOD7P2XM4-tYJz-------0.0007017543859649122
# kovacbb-------MDExOlB1bGxSZXF1ZXN0MzE3MjQ0NDY0-------0.0012165450121654502
# 400
# stof-------PR_kwDOCmABf85CSdka-------0.000700770847932726
# tomassasovsky-------PR_kwDOBZCz4M4xMIp4-------0.0011682242990654205
# colin3dmax-------PR_kwDOBXw_2M5AvOJ_-------0.0011641443538998836
# sebastiandenis-------MDExOlB1bGxSZXF1ZXN0NDU2NzA5NTIy-------0.0006949270326615705
# Acher1234-------PR_kwDOB2vfUM428YT8-------0.0014035087719298245
# maikelohcfg-------PR_kwDOCOtFQc4zsHpP-------0.0006997900629811056
# joyhope-------MDExOlB1bGxSZXF1ZXN0NTk4NzQ5MTU0-------0.0007017543859649122
# GJJ2019AppSynergies-------PR_kwDOAiEj5s5K4pqq-------0.000664451827242525
# yuwen-yan-------MDExOlB1bGxSZXF1ZXN0Mzc0NTE1Njgx-------0.0011627906976744186
# EmmanuelTobi-------MDExOlB1bGxSZXF1ZXN0NTY0NDY4NDM1-------0.0006724949562878278
# 10000Phone-------MDExOlB1bGxSZXF1ZXN0MjI3OTM0ODEw-------0.0007017543859649122
# 500
# 9527001-------MDExOlB1bGxSZXF1ZXN0NjUwNDQ0MTI=-------0.001272264631043257
# charleyzhu-------MDExOlB1bGxSZXF1ZXN0MzMxNzM0NjQ3-------0.002061855670103093
# vaibhavantil2-------MDExOlB1bGxSZXF1ZXN0NjYzNjQ3MjY0-------0.002105263157894737
# Akashsami-------MDExOlB1bGxSZXF1ZXN0Njg5NzMzNDM5-------0.0007017543859649122
# sh-cho-------PR_kwDOBFHeo85FX5Nw-------0.0013422818791946308
# sj-h4-------PR_kwDOCmABf85DFJuH-------0.0006688963210702341
# vanshg395-------MDExOlB1bGxSZXF1ZXN0MjA1NjMyMzI=-------0.0006949270326615705
# 570622566-------MDExOlB1bGxSZXF1ZXN0MzM5NjY1ODUy-------0.0006939625260235947
# AlexandrBoltris-------PR_kwDOAJ9R5M5KEPCZ-------0.0007012622720897616
# shihaohong-------MDExOlB1bGxSZXF1ZXN0MzIyNDE0ODk3-------0.0024449877750611247
# lollipopkit-------MDExOlB1bGxSZXF1ZXN0NDY4NzYzNDQ5-------0.0006393861892583121
# nilsreichardt-------PR_kwDOD0USHc5KsVYJ-------0.0006697923643670462
# aivuca-------MDExOlB1bGxSZXF1ZXN0MzI1ODc2Nzky-------0.0011641443538998836
# 600
# miquelbeltran-------MDExOlB1bGxSZXF1ZXN0NjA4MTc2MTI2-------0.0006882312456985547
# al-tush-------PR_kwDOD7P2XM4-tdRj-------0.0006968641114982578
# clarekang-------PR_kwDODTUYG85EMj65-------0.0006807351940095302
# pinboro-------PR_kwDOA7lyys5IRV10-------0.0007017543859649122
# shichunlei-------MDExOlB1bGxSZXF1ZXN0MTQyMTQyMTgz-------0.0036275695284159614
# Complay-------MDExOlB1bGxSZXF1ZXN0Mzc0Nzc2MDM2-------0.0012224938875305623
# denis-evteev-------PR_kwDOBy2NM85I9VzR-------0.0012224938875305623
# asavchuk-------MDExOlB1bGxSZXF1ZXN0Mzg3OTMwMDM1-------0.0006793478260869565
# iamsahilsonawane-------PR_kwDOCJkU7M4-aw-6-------0.0006531678641410843
# chunghha-------PR_kwDOD7P2XM5HXgWs-------0.0006613756613756613
# trashfeed-------MDExOlB1bGxSZXF1ZXN0Mjc4MDk1OTEy-------0.0006622516556291391
# 700
# cgestes-------PR_kwDOBm1m8M5K_ARb-------0.00461361014994233
# sumittiware-------MDExOlB1bGxSZXF1ZXN0NjMxNTA4OTgz-------0.00066711140760507
# ErfanRht-------MDExOlB1bGxSZXF1ZXN0MzM1NzEzMzcw-------0.0013745704467353953
# proninyaroslav-------MDExOlB1bGxSZXF1ZXN0NjI0NTEzOTQ5-------0.0006858710562414266
# mdanics-------PR_kwDOCYdRds4vwjj1-------0.004663557628247834
# JinhuaK-------PR_kwDOD0USHc5LIL55-------0.0006839945280437756
# BrightDV-------PR_kwDOBXw_2M5BMc_--------0.0034602076124567475
# badushaebrahim-------MDExOlB1bGxSZXF1ZXN0NTEwMTcyMjYw-------0.002277904328018223
# santoxyz-------MDExOlB1bGxSZXF1ZXN0NjExNTAyNzAy-------0.0012224938875305623
# lxp-git-------PR_kwDODBDVB85KUFL3-------0.0024067388688327317
# weiminghuaa-------MDExOlB1bGxSZXF1ZXN0Mjc4NzMwNDUz-------0.001176470588235294
# 800
# pablojimpas-------MDExOlB1bGxSZXF1ZXN0NDk1Njk5NTg4-------0.0012224938875305623
# JosefWN-------PR_kwDOCSpvU84wnA2C-------0.003667481662591687
# rofrol-------PR_kwDOCYFjg85GRTeM-------0.0006821282401091405
# ScriptAutomate-------MDExOlB1bGxSZXF1ZXN0NDk3NDI0NTI0-------0.008064516129032258
# jithuraj-------MDExOlB1bGxSZXF1ZXN0Mzc2MzMxNjY4-------0.0012911555842479018
# DanielArndt-------MDExOlB1bGxSZXF1ZXN0NjI5MjU1OTAz-------0.000655307994757536
# sduduzog-------PR_kwDOCF04Ls4wCgVC-------0.0024449877750611247
# mobolun-------MDExOlB1bGxSZXF1ZXN0Mzg2MTAzNTMz-------0.0006872852233676976
# bibash-mi-------MDExOlB1bGxSZXF1ZXN0NjAwNDUzNDcw-------0.0007017543859649122
# felipebueno-------MDExOlB1bGxSZXF1ZXN0NDk2MTE3NDk5-------0.0006784260515603799
# 900
# bipinct-------MDExOlB1bGxSZXF1ZXN0MzgyMDA4MDIw-------0.0006906077348066298
# jwaltz-------PR_kwDOA7lyys5IuUS8-------0.0035087719298245615
# juxjux9930-------PR_kwDOCxoIZM5Iy_TS-------0.002099370188943317
# gurfan-------PR_kwDOD7P2XM5BxW-_-------0.0035087719298245615
# twirling-jesters-------PR_kwDODp3qh85JXFWm-------0.0007017543859649122
# Humonitarian-------MDExOlB1bGxSZXF1ZXN0NTY1MTc1OTU4-------0.002102312543798178
# 1000
# simb11-------PR_kwDOCYFjg85KFlAy-------0.0007002801120448179
# F-OS-------PR_kwDOAqixHc4y_ONP-------0.0007017543859649122
# UrsulaMejor-------PR_kwDOAqixHc44GZXa-------0.002105263157894737
# Jalopkomit18-------PR_kwDOCYFjg844UGvv-------0.0007012622720897616
# ondrej008-------MDExOlB1bGxSZXF1ZXN0Mjc0NTc3MzAw-------0.0021037868162692847
# LeDrascol-------PR_kwDOBfYDC85Ab3NH-------0.0021037868162692847
# 1100
# MistakeNot4892-------PR_kwDOB40ng85JRhw2-------0.0033715441672285905
# xTrainx-------PR_kwDOCamu-c4--MIi-------0.0007012622720897616
# SpaceManiac-------PR_kwDOCamu-c45v6SJ-------0.000693000693000693
# Dorsisdwarf-------MDExOlB1bGxSZXF1ZXN0NDY5NDk0MDUx-------0.0007017543859649122
# ejones44-------MDExOlB1bGxSZXF1ZXN0NDgwOTg3Mzg3-------0.0012224938875305623
# Andrew-Fall-------PR_kwDODBDVB85KMOpF-------0.008433734939759036
# irgitahy-------PR_kwDOBrnV384-b1mK-------0.0024449877750611247
# rv4c4s-------PR_kwDOBkCXz84sNmIR-------0.0012224938875305623
# 1200
# SepuIka-------PR_kwDOAqixHc4608LW-------0.0007017543859649122
# GeneriedJenelle-------PR_kwDOAqixHc43eJLM-------0.013333333333333334
# ColonialMarines-Mirror-------PR_kwDOCGzUbs5KYE3E-------0.0007017543859649122
# Horatio22-------MDExOlB1bGxSZXF1ZXN0NTk0MzMxMDA1-------0.001215066828675577
# sum1won-------PR_kwDOBVMSls4w4ssM-------0.0012224938875305623
# Superspheres-------PR_kwDODp3qh85Jr11r-------0.0007002801120448179
# 1300
# lebensraum-------PR_kwDOB40ng85C0hq9-------0.0007017543859649122
# Eddyskingdom-------MDExOlB1bGxSZXF1ZXN0MTk1Njk1MzE=-------0.002105263157894737
# Dahlular-------MDExOlB1bGxSZXF1ZXN0NjA4Mjg4MTAw-------0.002807017543859649
# CaraS212-------PR_kwDOC60iJ844t_JF-------0.001218026796589525
# 1400
# 1500
# 1600
# enlego-------PR_kwDOABLXGs5J5auS-------0.01
# 1700
# thepeoplesbourgeois-------MDExOlB1bGxSZXF1ZXN0MTg5MjA1NjM5-------0.011904761904761904
# 1800
# 1900
# 2000
# thiagopromano-------MDExOlB1bGxSZXF1ZXN0MTE4MDc0MjMz-------0.01694915254237288
# 2100
# 2200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 print("Node1 ------ Node2 ------ Jacord Coeff")
# ----> 2 print(jaccard_link_prediction(B))
#
# Cell In[23], line 15, in jaccard_link_prediction(graph)
#      12 if node1 == node2 or graph.has_edge(node1, node2):
#      13     continue
# ---> 15 jaccard = jaccard_coefficient(graph, node1, node2)
#      16 if(jaccard != 0):
#      17     predicted_edges.append((node1, node2, jaccard))
#
# Cell In[9], line 4, in jaccard_coefficient(graph, node1, node2)
#       2 neighbors1 = set(graph.neighbors(node1))
#       3 neighbors2 = set(graph.neighbors(node2))
# ----> 4 intersection = neighbors1.intersection(neighbors2)
#       5 union = neighbors1.union(neighbors2)
#       6 if len(union) == 0:
#
# KeyboardInterrupt:

# %%
# preferential attachment 
def prefAttachment(graph):
    predicted_edges = []
    count = 10000
    userCount = 0
    for node1 in users:
        userCount += 1
        if(userCount%100 == 0):
            print(userCount)
        for node2 in issues:
            if node1 == node2 or graph.has_edge(node1, node2):
                continue
            score = nx.preferential_attachment(graph, (node1,node2))
            for u,v, p in score:
                print(f"({u}, {v}) -> {p}")
            # if(score != 0):
            #     predicted_edges.append((node1, node2, score))
            #     count -= 1
            #     if(count == 0):
            #         print(node1,end="-------")
            #         print(node2, end="-------")
            #         print(score)
                    # count = 10000
                    
    return sorted(predicted_edges, key=lambda x: x[2], reverse=True)

# %%
prefAttachment(B)

# %%
def adamic_adar_coefficient(graph, node1, node2):
    neighbors1 = set(graph.neighbors(node1))
    neighbors2 = set(graph.neighbors(node2))
    common_neighbors = neighbors1.intersection(neighbors2)
    aa = sum([1 / math.log(len(set(graph.neighbors(neighbor)))) for neighbor in common_neighbors])
    return aa

def adamic_adar_link_prediction(graph):
    predicted_edges = []
    for node1 in graph.nodes():
        for node2 in graph.nodes():
            if node1 == node2 or graph.has_edge(node1, node2):
                continue
            aa = adamic_adar_coefficient(graph, node1, node2)
            predicted_edges.append((node1, node2, aa))
    return sorted(predicted_edges, key=lambda x: x[2], reverse=True)

# %%
# compute the Adamic-Adar similarity between all pairs of users and issues
aa_matrix = np.zeros((len(users), len(issues)))
for u, i in combinations(range(len(users)), 2):
    u_vec = users_matrix[u].toarray()[0]
    i_vec = issues_matrix[i].toarray()[0]
    common = np.where(np.logical_and(u_vec, i_vec))[0]
    aa = 0
    for c in common:
        aa += 1 / np.log(len(np.where(users_matrix[:, c].toarray())[0]))
    aa_matrix[u][i] = aa
    aa_matrix[i][u] = aa

# %%
def katz(gph, set1, set2, alpha, beta, k):
    A = nx.bipartite.biadjacency_matrix(gph, row_order = set1, column_order = set2)
    m, n = A.shape
    A_L = nx.bipartite.projected_graph(gph, set1)
    A_R = nx.bipartite.projected_graph(gph, set2)
    A_pred = np.zeros((m, n))

    for i in range(k):
        # Calculate the Katz centrality of the left and right projection
        K_L = alpha * np.dot(A_L, K_L) + beta * A_L
        K_R = alpha * np.dot(A_R, K_R) + beta * A_R

        # Calculate the predicted adjacency matrix using the Katz scores
        A_pred = np.dot(K_L, K_R.T)

    return A_pred


def katz_bipartite_link_prediction(adj_matrix, beta, max_iterations, convergence_threshold=1e-6):

    # Compute the maximum eigenvalue of the adjacency matrix
    max_eigval = np.linalg.eigvals(adj_matrix).max()

    # Compute the Katz scores using the formula: (I - beta * A)^-1 - I
    katz_matrix = np.linalg.inv(np.eye(adj_matrix.shape[0]) - beta * adj_matrix) - np.eye(adj_matrix.shape[0])

    # Scale the Katz scores by powers of beta up to the maximum eigenvalue
    for i in range(max_iterations):
        katz_matrix *= beta
        if np.abs(katz_matrix).max() / max_eigval < convergence_threshold:
            break

    return katz_matrix

A = nx.bipartite.biadjacency_matrix(gph, row_order = users, column_order = issues)

adj_array = np.asarray(A.toarray())

# print(adj_array)

print(katz_bipartite_link_prediction(adj_array,0.1,1))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[49], line 41
#      37 adj_array = np.asarray(A.toarray())
#      39 # print(adj_array)
# ---> 41 print(katz_bipartite_link_prediction(adj_array,0.1,1))
#
# Cell In[49], line 22, in katz_bipartite_link_prediction(adj_matrix, beta, max_iterations, convergence_threshold)
#      19 def katz_bipartite_link_prediction(adj_matrix, beta, max_iterations, convergence_threshold=1e-6):
#      20
#      21     # Compute the maximum eigenvalue of the adjacency matrix
# ---> 22     max_eigval = np.linalg.eigvals(adj_matrix).max()
#      24     # Compute the Katz scores using the formula: (I - beta * A)^-1 - I
#      25     katz_matrix = np.linalg.inv(np.eye(adj_matrix.shape[0]) - beta * adj_matrix) - np.eye(adj_matrix.shape[0])
#
# File <__array_function__ internals>:200, in eigvals(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:1042, in eigvals(a)
#    1040 a, wrap = _makearray(a)
#    1041 _assert_stacked_2d(a)
# -> 1042 _assert_stacked_square(a)
#    1043 _assert_finite(a)
#    1044 t, result_t = _commonType(a)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:190, in _assert_stacked_square(*arrays)
#     188 m, n = a.shape[-2:]
#     189 if m != n:
# --> 190     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square
